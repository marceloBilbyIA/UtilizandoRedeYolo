# %% [markdown]
# <a href="https://colab.research.google.com/github/marceloBilbyIA/UtilizandoRedeYolo/blob/main/Utilizando_rede_Yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #INSTALL

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.72 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.0/112.6 GB disk)

# %% [markdown]
# #IMPORTS

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# #PREDICT

# %%
# !yolo predict model=yolo11n.pt source='/content/predict.jpeg'
# Out:
# Ultralytics 8.3.72 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# image 1/1 /content/predict.jpeg: 640x480 1 person, 1 bicycle, 1 dog, 43.6ms
# Speed: 2.7ms preprocess, 43.6ms inference, 139.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# #RESULT

# %%
img = mpimg.imread('/content/runs/detect/predict2/predict.jpg')
imgplot = plt.imshow(img)
plt.show()
